# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\1\\Desktop\\DL\\Dataset\\diabetes.csv')
data.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
x = data[['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level']].values
y = data['diabetes'].values  # 0 or 1
print (x.shape, y.shape)
# Out:
# (100000, 8) (100000,)

# %%
# visualizing the data
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], color='b', label='Non-Diabetic')
plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], color='r', label='Diabetic')
plt.xlabel('Glocose')
plt.ylabel('Blood Pressure')
plt.legend()

# %%
# splite the data to train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print ('Training sampile',x_train.shape, y_train.shape)
print ('Testing sampile',x_test.shape, y_test.shape)
# Out:
# Training sampile (80000, 8) (80000,)
# Testing sampile (20000, 8) (20000,)

# %%
# bulding Nueral Network
from keras.models import Sequential
from keras import layers

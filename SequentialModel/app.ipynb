# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\1\\Desktop\\DL\\Dataset\\insulin.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']].values
y = data['Outcome'].values  # 0 or 1
print (x.shape, y.shape)
# Out:
# (768, 8) (768,)

# %%
# visualizing the data
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], color='b', label='Non-Diabetic')
plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], color='r', label='Diabetic')
plt.xlabel('Glocose')
plt.ylabel('Blood Pressure')
plt.legend()

# %%
# splite the data to train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print ('Training sampile',x_train.shape, y_train.shape)
print ('Testing sampile',x_test.shape, y_test.shape)
# Out:
# Training sampile (614, 8) (614,)
# Testing sampile (154, 8) (154,)

# %%
import tensorflow as tf
import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.16.1
# Keras version: 3.1.1
